# %%
from PyParticleBunch import *
import numpy as np

# %%
beta_x = 3.215250830692
beta_y = 18.598794417925
alpha_x =  -0.547366008626
alpha_y =  2.750780302852
D_x =  -0.000103040524
D_xp = 0.001254020379
D_y = 0.
D_yp = 0.
emittance_x = emittance_y = 400 * 1E-6 * np.pi
x_limit = 5
y_limit = 5
n = 1E6

# %%
myMatchedGaussianBunch = ParticleBunch.MatchedGaussian_4D(n, emittance_x, emittance_y, alpha_x, beta_x, alpha_y, beta_y, x_limit = 5, y_limit = 5)

# %%
myMatchedGaussianBunch.plot_heatmap('x', 'xp', 'Gaussian_horizontal.png', 'Gaussian x-xp phase space')

# %%
myMatchedGaussianBunch.plot_heatmap('y', 'yp', 'Gaussian_vertical.png', 'Gaussian y-yp phase space')

# %%
myMatchedGaussianBunch.plot_heatmap('x', 'y', 'Gaussian_real.png', 'Gaussian x-y real space')

# %%
myMatchedGaussianBunch.plot_heatmap('t', 'pt', 'Gaussian_longitudinal.png', 'Gaussian t-pt phase space')

# %%
myMatchedWaterbagBunch = ParticleBunch.MatchedWaterbag_4D(n, emittance_x, emittance_y, alpha_x, beta_x, alpha_y, beta_y)

# %%
myMatchedWaterbagBunch.plot_heatmap('x', 'xp', 'Waterbag_horizontal.png', 'Waterbag x-xp phase space')

# %%
myMatchedWaterbagBunch.plot_heatmap('y', 'yp', 'Waterbag_vertical.png', 'Waterbag y-yp phase space')

# %%
myMatchedWaterbagBunch.plot_heatmap('x', 'y', 'Waterbag_real.png', 'Waterbag x-y real space')

# %%
myMatchedWaterbagBunch.plot_heatmap('t', 'pt', 'Waterbag_longitudinal.png', 'Waterbag t-pt phase space')

# %%
myMatchedKVBunch = ParticleBunch.MatchedKV_4D(n, emittance_x, emittance_y, alpha_x, beta_x, alpha_y, beta_y)

# %%
myMatchedKVBunch.plot_heatmap('x', 'xp', 'KV_horizontal.png', 'KV x-xp phase space')

# %%
myMatchedKVBunch.plot_heatmap('y', 'yp', 'KV_vertical.png', 'KV y-yp phase space')

# %%
myMatchedKVBunch.plot_heatmap('x', 'y', 'KV_real.png', 'KV x-y real space')

# %%
myMatchedKVBunch.plot_heatmap('t', 'pt', 'KV_longitudinal.png', 'KV t-pt phase space')

# %%
beta_x = 3.183218456327231
beta_y = 17.366440445018583
alpha_x =  -0.002213666757314968
alpha_y =  -0.0010751726719423877
D_x =  0.0003478381975430389
D_xp = -0.0010490010818251987
D_y = 0.
D_yp = 0.
emittance_x = emittance_y = 750 * 1E-6 * np.pi
min_sig = 0
max_sig = 10
n = 10
ISIS_II_EH_RCS_PoincareBunch = ParticleBunch.Poincare_2D(n, emittance_x, emittance_y, alpha_x, beta_x, alpha_y, beta_y, min_sig, max_sig)
# Out:
# MatchedBunchGenerator1D::Poincare_1D: Dispersion Not Set - Assuming to be ZERO

# %%
ISIS_II_EH_RCS_PoincareBunch.plot_heatmap('x', 'xp', 'ISIS_II_IH_RCS_Poincare_horizontal.png','Poincare x-xp phase space')

# %%
ISIS_II_EH_RCS_PoincareBunch.plot_heatmap('x', 'y', 'ISIS_II_IH_RCS_Poincare_real.png','Poincare x-y real space')

# %%
ISIS_II_EH_RCS_PoincareBunch.plot_heatmap('y', 'yp', 'ISIS_II_IH_RCS_Poincare_vertical.png','Poincare y-yp phase space')

# %%
ISIS_II_EH_RCS_PoincareBunch.plot_heatmap('t', 'pt', 'ISIS_II_IH_RCS_Poincare_longitudinal.png','Poincare t-pt phase space')

# %%
emittance_x = emittance_y = 750 * 1E-6 * np.pi
min_sig = 0
max_sig = 5
n_mp = 10
coordinate = 'x'
PoincareBunch = ParticleBunch.Poincare_1D(n_mp, coordinate, emittance_x, -0.00010928136671707634, 4.748197547872093, min_sig, max_sig)
# Out:
# x
# MatchedBunchGenerator1D::Poincare_1D: Dispersion Not Set - Assuming to be ZERO

# %%
PoincareBunch.plot_heatmap('x', 'y', '1D_Poincare_real.png','Poincare x-y real space')

# %%
PoincareBunch.plot_heatmap('x', 'xp', '1D_Poincare_horizontal.png','Poincare x-xp phase space')

# %% [markdown]
# ## Test dp in poincare bunch

# %%
beta_x = 3.183218456327231
beta_y = 17.366440445018583
alpha_x =  -0.002213666757314968
alpha_y =  -0.0010751726719423877
D_x =  0.0003478381975430389
D_xp = -0.0010490010818251987
D_y = 0.
D_yp = 0.
emittance_x = emittance_y = 750 * 1E-6 * np.pi
min_sig = 0
max_sig = 10
n = 10
coord = 'x'

# %%
PoincareBunch = ParticleBunch.Poincare_1D(n_mp, coord, emittance_x, alpha_x, beta_x, min_sig, max_sig, deltap=0.01, dispersion = D_x)
# Out:
# x

# %%
PoincareBunch.plot_heatmap('x', 'xp', 'dp_Poincare_horizontal.png','Poincare x-xp phase space')

# %%
PoincareBunch.plot_heatmap('y', 'yp', 'dp_Poincare_vertical.png','Poincare y-yp phase space')

# %%
PoincareBunch.plot_heatmap('x', 'y', 'dp_Poincare_real.png','Poincare x-y real space')

# %%
PoincareBunch.plot_heatmap('t', 'pt', 'dp_Poincare_longitudinal.png','Poincare t-pt phase space')

# %% [markdown]
# ## 2D deltap Poincare

# %%
beta_x = 3.183218456327231
beta_y = 17.366440445018583
alpha_x =  -0.002213666757314968
alpha_y =  -0.0010751726719423877
D_x =  0.0003478381975430389
D_xp = -0.0010490010818251987
D_y = 0.
D_yp = 0.
deltap = 0.01
emittance_x = emittance_y = 750 * 1E-6 * np.pi
min_sig = 0
max_sig = 10
n = 10
Deltap_2D_PoincareBunch = ParticleBunch.Poincare_2D(n, emittance_x, emittance_y, alpha_x, beta_x, alpha_y, beta_y, min_sig, max_sig, deltap, D_x, D_y)

# %%
Deltap_2D_PoincareBunch.plot_heatmap('t', 'pt', '2D_dp_Poincare_longitudinal.png','Poincare t-pt phase space')

# %%
Deltap_2D_PoincareBunch.plot_heatmap('x', 'y', '2D_dp_Poincare_real.png','Poincare x-y real space')

# %%
Deltap_2D_PoincareBunch.plot_heatmap('x', 'xp', '2D_dp_Poincare_horizontal.png','Poincare x-xp phase space')

# %%
Deltap_2D_PoincareBunch.plot_heatmap('y', 'yp', '2D_dp_Poincare_vertical.png','Poincare y-yp phase space')
